# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2020&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7fee36c5c700>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2020              8
# 1       Digital    OverDrive        EBOOK          2020              8
# 2       Digital    OverDrive        EBOOK          2020              8
# 3       Digital    OverDrive        EBOOK          2020              8
# 4       Digital    OverDrive        EBOOK          2020              8
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2020              1
# 9996   Physical      Horizon         BOOK          2020              1
# 9997   Physical      Horizon         BOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
# 9999    Digital    OverDrive        EBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %% [markdown]
# # * Tabellen mergen für 2019/2020
# # * Ausleihvergleiche Jahre
# # * Ausleihvergleiche Jahre/Verlage

# %%
checkouts_df[(checkouts_df["materialtype"] == "AUDIOBOOK") & (checkouts_df["publisher"] == "Macmillan Audio")]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 204     Digital    OverDrive    AUDIOBOOK          2020              5
# 254     Digital    OverDrive    AUDIOBOOK          2020              1
# 339     Digital    OverDrive    AUDIOBOOK          2020              1
# 575     Digital    OverDrive    AUDIOBOOK          2020              1
# 693     Digital    OverDrive    AUDIOBOOK          2020              1
# 699     Digital    OverDrive    AUDIOBOOK          2020              1
# 844     Digital    OverDrive    AUDIOBOOK          2020              1
# 847     Digital    OverDrive    AUDIOBOOK          2020              1
# 914     Digital    OverDrive    AUDIOBOOK          2020              1
# 1065    Digital    OverDrive    AUDIOBOOK          2020              1
# 1175    Digital    OverDrive    AUDIOBOOK          2020              1
# 1218    Digital    OverDrive    AUDIOBOOK          2020              1
# ...

# %%
checkouts_audiobooks_macmillan_df = checkouts_df[(checkouts_df["materialtype"] == "AUDIOBOOK") & (checkouts_df["publisher"] == "Macmillan Audio")]

# %%
checkouts_audiobooks_macmillan_df [["checkouts", "publisher", "materialtype"]]
# Out:
#       checkouts        publisher materialtype
# 204           3  Macmillan Audio    AUDIOBOOK
# 254           1  Macmillan Audio    AUDIOBOOK
# 339           6  Macmillan Audio    AUDIOBOOK
# 575          10  Macmillan Audio    AUDIOBOOK
# 693           3  Macmillan Audio    AUDIOBOOK
# 699           9  Macmillan Audio    AUDIOBOOK
# 844           3  Macmillan Audio    AUDIOBOOK
# 847          29  Macmillan Audio    AUDIOBOOK
# 914           1  Macmillan Audio    AUDIOBOOK
# 1065          9  Macmillan Audio    AUDIOBOOK
# 1175          3  Macmillan Audio    AUDIOBOOK
# 1218          9  Macmillan Audio    AUDIOBOOK
# 2490         16  Macmillan Audio    AUDIOBOOK
# 2491          4  Macmillan Audio    AUDIOBOOK
# 2577          2  Macmillan Audio    AUDIOBOOK
# 2666          2  Macmillan Audio    AUDIOBOOK
# 2847          1  Macmillan Audio    AUDIOBOOK
# 2890          8  Macmillan Audio    AUDIOBOOK
# 3146         13  Macmillan Audio    AUDIOBOOK
# ...

# %%
checkouts_audiobooks_macmillan_df.value_counts("checkouts")
# Out:
# checkouts
# 3     14
# 2     11
# 1      6
# 9      5
# 4      4
# 13     3
# 8      3
# 10     2
# 6      2
# 5      1
# 15     1
# 16     1
# 17     1
# 29     1
# 35     1
# 75     1
# 90     1
# dtype: int64

# %%
checkouts_audiobooks_macmillan_df.groupby("publisher").sum() [["checkouts"]]
# Out:
#                  checkouts
# publisher
# Macmillan Audio        508
