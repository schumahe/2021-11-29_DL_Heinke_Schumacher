# %% [markdown]
# # Für welche Titel und Verlage betragen die Ausleihen mehr als 75?

# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2020&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f5d6fdd7820>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2020              8
# 1       Digital    OverDrive        EBOOK          2020              8
# 2       Digital    OverDrive        EBOOK          2020              8
# 3       Digital    OverDrive        EBOOK          2020              8
# 4       Digital    OverDrive        EBOOK          2020              8
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2020              1
# 9996   Physical      Horizon         BOOK          2020              1
# 9997   Physical      Horizon         BOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
# 9999    Digital    OverDrive        EBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df.shape
# Out:
# (10000, 11)

# %%
checkouts_df.columns
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %% [markdown]
# ## Anzeige der 50 höchsten Checkouts-Werte, Filterung nach Höchstwert=75

# %%
checkouts_df.sort_values(by=["checkouts"], ascending=False).head(50)
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 5096    Digital    OverDrive        EBOOK          2020              1
# 256    Physical      Horizon         BOOK          2020              1
# 9106    Digital    OverDrive        EBOOK          2020              1
# 620     Digital    OverDrive        EBOOK          2020              1
# 4890    Digital    OverDrive        EBOOK          2020              1
# 2254    Digital    OverDrive        EBOOK          2020              1
# 2897   Physical      Horizon         BOOK          2020              1
# 5199   Physical      Horizon    VIDEODISC          2020              1
# 5430    Digital    OverDrive    AUDIOBOOK          2020              1
# 4754    Digital    OverDrive        EBOOK          2020              1
# 9859    Digital    OverDrive        EBOOK          2020              1
# 7507    Digital    OverDrive        EBOOK          2020              1
# ...

# %%
checkouts_df[checkouts_df["checkouts"] >= 75].sort_values(by=["checkouts"], ascending=False)
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 5096    Digital    OverDrive        EBOOK          2020              1
# 256    Physical      Horizon         BOOK          2020              1
# 9106    Digital    OverDrive        EBOOK          2020              1
# 620     Digital    OverDrive        EBOOK          2020              1
# 4890    Digital    OverDrive        EBOOK          2020              1
# 2254    Digital    OverDrive        EBOOK          2020              1
# 2897   Physical      Horizon         BOOK          2020              1
# 5199   Physical      Horizon    VIDEODISC          2020              1
# 5430    Digital    OverDrive    AUDIOBOOK          2020              1
# 4754    Digital    OverDrive        EBOOK          2020              1
# 7507    Digital    OverDrive        EBOOK          2020              1
# 9859    Digital    OverDrive        EBOOK          2020              1
# ...

# %%
checkouts_75_df = checkouts_df[checkouts_df["checkouts"] >= 75].sort_values(by=["checkouts"], ascending=False)

# %%
checkouts_75_df [["checkouts", "title", "publisher"]]
# Out:
#       checkouts                                              title  \
# 5096        546                            Where the Crawdads Sing
# 256         355                           Exhalation / Ted Chiang.
# 9106        322                   Little Fires Everywhere: A Novel
# 620         218                           Between the World and Me
# 4890        190                                              Circe
# 2254        162                             The Guardians: A Novel
# 2897        145                 The night fire / Michael Connelly.
# 5199        120  Stuber / Twentieth Century Fox ; produced by J...
# 5430        114  The Hunger Games: The Hunger Games Series, Boo...
# 4754        108                                     The Fifth Risk
# 7507        107                Outlander: Outlander Series, Book 1
# 9859        107  Girl, Woman, Other: A Novel (Booker Prize Winner)
# 1885        103                             Sharp Objects: A Novel
# ...

# %%
checkouts_75_df [["checkouts", "title"]]
# Out:
#       checkouts                                              title
# 5096        546                            Where the Crawdads Sing
# 256         355                           Exhalation / Ted Chiang.
# 9106        322                   Little Fires Everywhere: A Novel
# 620         218                           Between the World and Me
# 4890        190                                              Circe
# 2254        162                             The Guardians: A Novel
# 2897        145                 The night fire / Michael Connelly.
# 5199        120  Stuber / Twentieth Century Fox ; produced by J...
# 5430        114  The Hunger Games: The Hunger Games Series, Boo...
# 4754        108                                     The Fifth Risk
# 7507        107                Outlander: Outlander Series, Book 1
# 9859        107  Girl, Woman, Other: A Novel (Booker Prize Winner)
# 1885        103                             Sharp Objects: A Novel
# ...

# %%
checkouts_75_df [["checkouts", "publisher"]]
# Out:
#       checkouts                                  publisher
# 5096        546                  Penguin Group (USA), Inc.
# 256         355                           Alfred A. Knopf,
# 9106        322                  Penguin Group (USA), Inc.
# 620         218                         Random House, Inc.
# 4890        190                     Hachette Digital, Inc.
# 2254        162                         Random House, Inc.
# 2897        145                 Little, Brown and Company,
# 5199        120  Twentieth Century Fox Home Entertainment,
# 5430        114                 Scholastic Inc. Audiobooks
# 4754        108                     W. W. Norton & Company
# 7507        107                         Random House, Inc.
# 9859        107                       Lightning Source Inc
# 1885        103                         Random House, Inc.
# 1815        101                              Books on Tape
# 3789        100                                 Lionsgate,
# ...

# %% [markdown]
# ## Graphische Darstellung

# %%
checkouts_75_df.plot(figsize=(8,8), kind="barh", x="publisher", y=("checkouts"), color="red", title="Ausleihen höher als 75 per Verlag", fontsize=10)
# Out:
# <AxesSubplot:title={'center':'Ausleihen höher als 75 per Verlag'}, ylabel='publisher'>

# %% [markdown]
# ### Leider habe ich für die nächste Graphik noch nicht herausgefrickelt bekommen, wie sich die tick-length verringern läßt, das wäre noch klasse hinzukriegen, ich suche weiter.

# %%
checkouts_75_df.plot(figsize=(10,5), kind="bar", title="Ausleihen höher als 75 per Titel", x="title", y="checkouts", fontsize=10)
# Out:
# <AxesSubplot:title={'center':'Ausleihen höher als 75 per Titel'}, xlabel='title'>
