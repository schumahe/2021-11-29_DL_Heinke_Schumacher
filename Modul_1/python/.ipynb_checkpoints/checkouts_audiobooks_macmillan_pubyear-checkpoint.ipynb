# %% [markdown]
# # Checkouts Audiobooks per Publ.-jahr für den Verlag Mcmillan in 2020?

# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2020&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7faaaac59880>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2020              8
# 1       Digital    OverDrive        EBOOK          2020              8
# 2       Digital    OverDrive        EBOOK          2020              8
# 3       Digital    OverDrive        EBOOK          2020              8
# 4       Digital    OverDrive        EBOOK          2020              8
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2020              1
# 9996   Physical      Horizon         BOOK          2020              1
# 9997   Physical      Horizon         BOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
# 9999    Digital    OverDrive        EBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df.materialtype.unique()
# Out:
# array(['BOOK', 'EBOOK', 'AUDIOBOOK', 'SOUNDDISC', 'VIDEO', 'VIDEODISC',
#        'ER, SOUNDDISC', 'MUSIC', 'LARGEPRINT', 'REGPRINT',
#        'SOUNDDISC, VIDEODISC', 'VISUAL', 'CR', 'ER'], dtype=object)

# %% [markdown]
# ## Filterung nach Materialtyp

# %%
checkouts_df[checkouts_df["materialtype"] == "AUDIOBOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 8       Digital    OverDrive    AUDIOBOOK          2020              8
# 19      Digital    OverDrive    AUDIOBOOK          2020              8
# 36      Digital    OverDrive    AUDIOBOOK          2020              8
# 41      Digital    OverDrive    AUDIOBOOK          2020              8
# 55      Digital    OverDrive    AUDIOBOOK          2020              2
# ...         ...          ...          ...           ...            ...
# 9939    Digital    OverDrive    AUDIOBOOK          2020              1
# 9942    Digital    OverDrive    AUDIOBOOK          2020              1
# 9971    Digital    OverDrive    AUDIOBOOK          2020              1
# 9981    Digital    OverDrive    AUDIOBOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %% [markdown]
# ## Definition DataFrame Materialtyp

# %%
checkouts_audiobooks_df = checkouts_df[checkouts_df["materialtype"] == "AUDIOBOOK"]

# %%
checkouts_audiobooks_df [["checkouts", "publisher", "materialtype"]]
# Out:
#       checkouts                      publisher materialtype
# 8             1         Blackstone Audio, Inc.    AUDIOBOOK
# 19            3     Random House Group Limited    AUDIOBOOK
# 36            1                 Hachette Audio    AUDIOBOOK
# 41            1                      Zondervan    AUDIOBOOK
# 55            4  Simon & Schuster - Audiobooks    AUDIOBOOK
# ...         ...                            ...          ...
# 9939          1         Blackstone Audio, Inc.    AUDIOBOOK
# 9942          1               Sounds True, Inc    AUDIOBOOK
# 9971          2              Tantor Media, Inc    AUDIOBOOK
# 9981          2            Recorded Books, LLC    AUDIOBOOK
# 9998          2                 Hachette Audio    AUDIOBOOK
#
# [1179 rows x 3 columns]

# %%
checkouts_audiobooks_df["publisher"].value_counts()
# Out:
# Books on Tape                                                 294
# Blackstone Audio, Inc.                                        227
# HarperCollins Publishers Inc.                                 141
# Tantor Media, Inc                                             103
# Macmillan Audio                                                58
# Recorded Books, LLC                                            54
# Simon & Schuster - Audiobooks                                  53
# HighBridge Company                                             31
# Hachette Audio                                                 28
# Dreamscape Media, LLC                                          27
# Scholastic Inc. Audiobooks                                     19
# Random House Group Limited                                     18
# Gildan Media Corp                                              16
# Naxos of America, Inc.                                         11
# ...

# %% [markdown]
# ## Auswahl/Filterung/Definition DataFrame des Verlages

# %%
checkouts_audiobooks_df[checkouts_audiobooks_df["publisher"] == "Macmillan Audio"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 204     Digital    OverDrive    AUDIOBOOK          2020              5
# 254     Digital    OverDrive    AUDIOBOOK          2020              1
# 339     Digital    OverDrive    AUDIOBOOK          2020              1
# 575     Digital    OverDrive    AUDIOBOOK          2020              1
# 693     Digital    OverDrive    AUDIOBOOK          2020              1
# 699     Digital    OverDrive    AUDIOBOOK          2020              1
# 844     Digital    OverDrive    AUDIOBOOK          2020              1
# 847     Digital    OverDrive    AUDIOBOOK          2020              1
# 914     Digital    OverDrive    AUDIOBOOK          2020              1
# 1065    Digital    OverDrive    AUDIOBOOK          2020              1
# 1175    Digital    OverDrive    AUDIOBOOK          2020              1
# 1218    Digital    OverDrive    AUDIOBOOK          2020              1
# ...

# %%
checkouts_audiobooks_macmillan_df = checkouts_audiobooks_df[checkouts_audiobooks_df["publisher"] == "Macmillan Audio"]

# %% [markdown]
# ## Sortierung/Gruppierung nach Publikationsjahr

# %%
checkouts_audiobooks_macmillan_df.sort_values(by="publicationyear")[["checkouts", "checkoutmonth", "publicationyear"]]
# Out:
#       checkouts  checkoutmonth publicationyear
# 1175          3              1            2008
# 4019          5              1            2009
# 4586          1              1            2010
# 2666          2              1            2010
# 5663         35              1            2011
# 5145          9              1            2011
# 5549          1              1            2012
# 2577          2              1            2012
# 699           9              1            2012
# 4950          2              1            2012
# 9747          4              1            2013
# 914           1              1            2013
# 4822          8              1            2014
# 7452          3              1            2014
# 8781          2              1            2014
# 3478          3              1            2014
# 7625          2              1            2015
# 7936          4              1            2015
# 7289         75              1            2015
# ...

# %%
checkouts_audiobooks_macmillan_df.groupby("publicationyear").sum() [["checkouts"]]
# Out:
#                  checkouts
# publicationyear
# 2008                     3
# 2009                     5
# 2010                     3
# 2011                    44
# 2012                    14
# 2013                     5
# 2014                    16
# 2015                   114
# 2016                    42
# 2017                    37
# 2018                    39
# 2019                   186

# %% [markdown]
# ## Definition DataFrame graphische Darstellung & Abbildung

# %%
checkouts_audiobooks_pubyear_macmillan_df = checkouts_audiobooks_macmillan_df.groupby("publicationyear").sum() [["checkouts"]]

# %%
checkouts_audiobooks_pubyear_macmillan_df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='publicationyear'>

# %%
checkouts_audiobooks_pubyear_macmillan_df.plot(kind="pie", y="checkouts", fontsize=12, figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='checkouts'>

# %% [markdown]
# # Variation: Verkürzung und Gruppierungsvariante

# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2020&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7fd87191e850>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2020              8
# 1       Digital    OverDrive        EBOOK          2020              8
# 2       Digital    OverDrive        EBOOK          2020              8
# 3       Digital    OverDrive        EBOOK          2020              8
# 4       Digital    OverDrive        EBOOK          2020              8
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2020              1
# 9996   Physical      Horizon         BOOK          2020              1
# 9997   Physical      Horizon         BOOK          2020              1
# 9998    Digital    OverDrive    AUDIOBOOK          2020              1
# 9999    Digital    OverDrive        EBOOK          2020              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_audiobooks_macmillan_df = checkouts_df[(checkouts_df["materialtype"] == "AUDIOBOOK") & 
                                                 (checkouts_df["publisher"] == "Macmillan Audio")]

# %%
checkouts_audiobooks_macmillan_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 204     Digital    OverDrive    AUDIOBOOK          2020              5
# 254     Digital    OverDrive    AUDIOBOOK          2020              1
# 339     Digital    OverDrive    AUDIOBOOK          2020              1
# 575     Digital    OverDrive    AUDIOBOOK          2020              1
# 693     Digital    OverDrive    AUDIOBOOK          2020              1
# 699     Digital    OverDrive    AUDIOBOOK          2020              1
# 844     Digital    OverDrive    AUDIOBOOK          2020              1
# 847     Digital    OverDrive    AUDIOBOOK          2020              1
# 914     Digital    OverDrive    AUDIOBOOK          2020              1
# 1065    Digital    OverDrive    AUDIOBOOK          2020              1
# 1175    Digital    OverDrive    AUDIOBOOK          2020              1
# 1218    Digital    OverDrive    AUDIOBOOK          2020              1
# ...

# %%
checkouts_audiobooks_macmillan_df.groupby("publicationyear").agg({"checkouts": ["sum"]})
# Out:
#                 checkouts
#                       sum
# publicationyear
# 2008                    3
# 2009                    5
# 2010                    3
# 2011                   44
# 2012                   14
# 2013                    5
# 2014                   16
# 2015                  114
# 2016                   42
# 2017                   37
# 2018                   39
# 2019                  186

# %%
checkouts_audiobooks_pubyear_macmillan_df = checkouts_audiobooks_macmillan_df.groupby("publicationyear").agg({"checkouts": ["sum"]})

# %%
# %matplotlib inline

# %%
checkouts_audiobooks_pubyear_macmillan_df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='publicationyear'>

# %%
checkouts_audiobooks_pubyear_macmillan_df.plot(kind="pie", y="checkouts", fontsize=12, figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='sum'>
