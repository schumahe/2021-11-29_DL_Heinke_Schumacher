# %% [markdown]
# ### 1. Erstelle eine Beschreibung des Datensatzes unter Verwendung des statistischen Grundvokabulars. --> Siehe Aufgabe 2.1

# %% [markdown]
# ### 2. Lies den Datensatz ein.

# %%
import pandas as pd
df = pd.read_csv("/home/schumahe/Schumacher/Modul_3/statistics/data/Library_Usage.csv", na_values="None")
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %% [markdown]
# ### 3. Bereinige den Datensatz von fehlenden Werten und berechne die neue Variable Membership Duration.

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)
df['Circulation Active Month']
# Out:
# 0               NaT
# 1        1900-04-01
# 2               NaT
# 3               NaT
# 4        1900-01-01
#             ...
# 423443   1900-03-01
# 423444   1900-07-01
# 423445   1900-07-01
# 423446   1900-04-01
# 423447          NaT
# Name: Circulation Active Month, Length: 423448, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month
df['Circulation Active Month']
# Out:
# 0         NaN
# 1         4.0
# 2         NaN
# 3         NaN
# 4         1.0
#          ...
# 423443    3.0
# 423444    7.0
# 423445    7.0
# 423446    4.0
# 423447    NaN
# Name: Circulation Active Month, Length: 423448, dtype: float64

# %%
df['Membership Duration'] = (
    df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...
