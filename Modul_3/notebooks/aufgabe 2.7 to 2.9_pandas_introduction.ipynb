# %% [markdown]
# ### Aufgabe 2.7: Datentypen

# %%
# None, "None" = strings
# 5 = int, "5" = string
# "NaN", NaN = strings
# True = boolean, "True" = string

# %%
import pandas as pd
df = pd.read_csv("/home/schumahe/Schumacher/Modul_3/data/Library_Usage.csv")
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df.head(60)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# 5                  3                 SENIOR                0               0
# 6                  0                  ADULT             3002            1689
# 7                  0                  ADULT                4               0
# 8                  0                  ADULT               20               0
# 9                  0                  ADULT                3               1
# 10                 0                  ADULT              102              31
# ...

# %% [markdown]
# ### Aufgabe 2.8: Exkurs Fehlende Werte

# %%
# Circulation Active Month, Circulation Active Year, Supervisor District

# %%
df = pd.read_csv("../data/Library_Usage.csv", na_values="NaN")
df['Circulation Active Year'] = pd.to_numeric(df['Circulation Active Year'], errors ='coerce')
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors ='coerce',
    format ="%B")

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df.dropna()
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      0                  ADULT               31
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# 7                      0                  ADULT                4
# 8                      0                  ADULT               20
# ...                  ...                    ...              ...
# 423442                 2            YOUNG ADULT              608
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
#
#         Total Renewals       Age Range Home Library Code  \
# 1                   22  25 to 34 years                S7
# 4                   11  45 to 54 years                M2
# ...

# %%
df.to_csv("/home/schumahe/Schumacher/Modul_3/data/Library_Usage_Clean.csv")

# %% [markdown]
# ### Aufgabe 2.9: Pandas Funktionen

# %%
df.head(100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# ..               ...                    ...              ...             ...
# 95                 0                  ADULT                0               0
# 96                 0                  ADULT               11               0
# 97                 0                  ADULT              160              44
# 98                 0                  ADULT               11               3
# 99                 0                  ADULT               40               0
#
# ...

# %%
df.head(n=100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# ..               ...                    ...              ...             ...
# 95                 0                  ADULT                0               0
# 96                 0                  ADULT               11               0
# 97                 0                  ADULT              160              44
# 98                 0                  ADULT               11               3
# 99                 0                  ADULT               40               0
#
# ...
