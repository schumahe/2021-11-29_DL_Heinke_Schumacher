# %% [markdown]
# ### Aufgabe 3.3: Ausreisserentfernung I

# %%
import pandas as pd 
df = pd.read_csv("/home/schumahe/Schumacher/Modul_3/data/Library_Usage.csv")

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Total Checkouts'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.25      2.0
# 0.50     19.0
# 0.75    113.0
# Name: Total Checkouts, dtype: float64

# %%
alpha = 0.005
df['Total Checkouts'].quantile([alpha, 1-alpha])
# Out:
# 0.005       0.00
# 0.995    2827.53
# Name: Total Checkouts, dtype: float64

# %%
alpha = 0.0015
df['Total Checkouts'].quantile([alpha, 1-alpha])
# Out:
# 0.0015       0.0000
# 0.9985    4286.8295
# Name: Total Checkouts, dtype: float64

# %%
ohne_ausreisser = (df['Total Checkouts'] != 0) & (df['Total Checkouts'] != (df['Total Checkouts'] >= 4286)) 
df.loc[ohne_ausreisser]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      0                  ADULT               31
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# 7                      0                  ADULT                4
# 8                      0                  ADULT               20
# ...                  ...                    ...              ...
# 423442                 2            YOUNG ADULT              608
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
#
#         Total Renewals       Age Range Home Library Code  \
# 1                   22  25 to 34 years                S7
# 4                   11  45 to 54 years                M2
# ...

# %%
# Ausreißer entfernen durch Ermittlung der äußeren Ränder mittels Quantile tangiert keine weiteren/anderen Werte, 
# scheint sinnvoll. Individueller aber gestaltbar durch Methode .value_counts Werte listen, 
# dann die gewünschten Ausreißer entfernen. Quantilen entfernen bedeutet ja immer das Entfernen
# von Gruppen von Werten
