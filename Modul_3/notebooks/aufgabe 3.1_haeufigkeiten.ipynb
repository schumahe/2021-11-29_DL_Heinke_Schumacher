# %% [markdown]
# ### Aufgabe 3.1: Häufigkeiten

# %%
import pandas as pd
df = pd.read_csv("/home/schumahe/Schumacher/Modul_3/data/Library_Usage.csv")
df['Age Range'].value_counts()
# Out:
# 25 to 34 years       91083
# 35 to 44 years       67390
# 10 to 19 years       58944
# 45 to 54 years       52492
# 0 to 9 years         38242
# 65 to 74 years       30141
# 20 to 24 years       29761
# 55 to 59 years       21230
# 60 to 64 years       19800
# 75 years and over    14150
# Name: Age Range, dtype: int64

# %%
df['Age Range'].value_counts(normalize=True)
# Out:
# 25 to 34 years       0.215208
# 35 to 44 years       0.159227
# 10 to 19 years       0.139271
# 45 to 54 years       0.124026
# 0 to 9 years         0.090357
# 65 to 74 years       0.071216
# 20 to 24 years       0.070318
# 55 to 59 years       0.050161
# 60 to 64 years       0.046783
# 75 years and over    0.033433
# Name: Age Range, dtype: float64

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
age_mode = df['Age Range'].mode()

# %%
age_mode[0] # wo kommt die 0 her?
# Out:
# '25 to 34 years'

# %% [markdown]
# ### Aufgabe 3.1: Häufigkeiten

# %%
df['Year Patron Registered'].value_counts()
# Out:
# 2003    69257
# 2015    53951
# 2014    51902
# 2013    48251
# 2012    37395
# 2011    26531
# 2016    26288
# 2010    24321
# 2009    22307
# 2008    20518
# 2007    13289
# 2006    10776
# 2005     9668
# 2004     8994
# Name: Year Patron Registered, dtype: int64

# %%
df.groupby('Year Patron Registered') # warum geht das nicht?

# %%
df['Year Patron Registered'].value_counts(normalize=True) * 100 # Listung absteigend nach Häufigkeit
# Out:
# 2003    16.355491
# 2015    12.740880
# 2014    12.256995
# 2013    11.394788
# 2012     8.831073
# 2011     6.265468
# 2016     6.208082
# 2010     5.743562
# 2009     5.267943
# 2008     4.845459
# 2007     3.138284
# 2006     2.544823
# 2005     2.283161
# 2004     2.123992
# Name: Year Patron Registered, dtype: float64

# %%
df['Age Range'].value_counts(normalize=True) * 100
# Out:
# 25 to 34 years       21.520770
# 35 to 44 years       15.922671
# 10 to 19 years       13.927080
# 45 to 54 years       12.402625
# 0 to 9 years          9.035685
# 65 to 74 years        7.121609
# 20 to 24 years        7.031824
# 55 to 59 years        5.016149
# 60 to 64 years        4.678274
# 75 years and over     3.343312
# Name: Age Range, dtype: float64

# %%
df['Age Range'].value_counts()
# Out:
# 25 to 34 years       91083
# 35 to 44 years       67390
# 10 to 19 years       58944
# 45 to 54 years       52492
# 0 to 9 years         38242
# 65 to 74 years       30141
# 20 to 24 years       29761
# 55 to 59 years       21230
# 60 to 64 years       19800
# 75 years and over    14150
# Name: Age Range, dtype: int64

# %%
df.head(60)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# 5                  3                 SENIOR                0               0
# 6                  0                  ADULT             3002            1689
# 7                  0                  ADULT                4               0
# 8                  0                  ADULT               20               0
# 9                  0                  ADULT                3               1
# 10                 0                  ADULT              102              31
# ...

# %%
df['Age Range'].fillna(df['Age Range'].mode())
# Out:
# 0         20 to 24 years
# 1         25 to 34 years
# 2         45 to 54 years
# 3         25 to 34 years
# 4         45 to 54 years
#                ...
# 423443    10 to 19 years
# 423444    60 to 64 years
# 423445      0 to 9 years
# 423446    10 to 19 years
# 423447      0 to 9 years
# Name: Age Range, Length: 423448, dtype: object

# %%
df['Age Range'].fillna(age_mode[0])
# Out:
# 0         20 to 24 years
# 1         25 to 34 years
# 2         45 to 54 years
# 3         25 to 34 years
# 4         45 to 54 years
#                ...
# 423443    10 to 19 years
# 423444    60 to 64 years
# 423445      0 to 9 years
# 423446    10 to 19 years
# 423447      0 to 9 years
# Name: Age Range, Length: 423448, dtype: object

# %%
df.head(60)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# 5                  3                 SENIOR                0               0
# 6                  0                  ADULT             3002            1689
# 7                  0                  ADULT                4               0
# 8                  0                  ADULT               20               0
# 9                  0                  ADULT                3               1
# 10                 0                  ADULT              102              31
# ...

# %%
df["agefill"] = df['Age Range'].fillna("25 to 34 years")

# %%
df.head(60)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# 5                  3                 SENIOR                0               0
# 6                  0                  ADULT             3002            1689
# 7                  0                  ADULT                4               0
# 8                  0                  ADULT               20               0
# 9                  0                  ADULT                3               1
# 10                 0                  ADULT              102              31
# ...

# %%
# schlechte Methode fehlende Werte zu ersetzen, weil die Werte der Gruppe unsauber werden 
# sowie alle Verhältnisse zu anderen Werten auch
